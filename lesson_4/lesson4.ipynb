# %% [markdown]
# ### 第四课 控制结构
# 1. 顺序结构： 符合计算机处理器基本逻辑，按照代码顺序依次执行。
#     + 计算本地时间，公式
#     + ![本地文件](image.png)
# 2. 循环结构
#     + while的其他作用：
#       + 循环体可以为空
#       + 如：清空输入区直到换行：`while((c = getchar()) != '\n');`
#     + 控制输入数据
#       + scanf函数的返回值
#         + -1 ： 输入出错，文件结束
#         + 0 ： 没有成功输入
#         + a(a>=1):成功输入多少个数据
#     + ![本地文件](image2.png)
#     + for 循环
#       + 逗号运算符：由逗号分割的多个表达式，从左到右依次计算。
#       + ![本地文件](image3.png)
#     + <u> 打表法：多组数据时，可以通过递推、动态规划算出数据内的数，然后直接查出
#     + 以空间换时间</u>
